# %%
import glob
from pandas import DataFrame as df
import numpy as np
import datetime

# %%
start=datetime.datetime.now()

# %%
items=glob.glob('/kaggle/input/repository/spMohanty-PlantVillage-Dataset-442d23a/raw/segmented/Grape*/*.jpg',recursive=True)
data=df(columns=['Item'],data=items)
data['Folder']=data['Item'].str.rsplit('/', 1, expand=True)[0]
data['Folder']=data['Folder'].str.rsplit('/', 1, expand=True)[1]
data['Species']=data['Folder'].str.rsplit('___', 1, expand=True)[0]
data['Disease']=data['Folder'].str.rsplit('___', 1, expand=True)[1]
data['Image Path']=data['Item']
data.drop(['Species','Item','Folder'],axis=1,inplace=True)
data.head()
# Out:
#                 Disease                                         Image Path
# 0  Esca_(Black_Measles)  /kaggle/input/repository/spMohanty-PlantVillag...
# 1  Esca_(Black_Measles)  /kaggle/input/repository/spMohanty-PlantVillag...
# 2  Esca_(Black_Measles)  /kaggle/input/repository/spMohanty-PlantVillag...
# 3  Esca_(Black_Measles)  /kaggle/input/repository/spMohanty-PlantVillag...
# 4  Esca_(Black_Measles)  /kaggle/input/repository/spMohanty-PlantVillag...

# %%
X=data.drop(['Disease'],axis=1)
y=data['Disease']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42, stratify=y)

# %%
import matplotlib.pyplot as plt
import cv2
# %matplotlib inline

# %%
img_train=[]
for image in X_train['Image Path']:
    img_train.append(cv2.imread(image,1))

# %%
imgplot=plt.imshow(cv2.cvtColor(img_train[0], cv2.COLOR_BGR2RGB))
plt.axis("off")
plt.title(y_train[0])
plt.show()

# %%
img_test=[]
for image in X_test['Image Path']:
    img_test.append(cv2.imread(image,1))

# %%
imgplot=plt.imshow(cv2.cvtColor(img_test[0], cv2.COLOR_BGR2RGB))
plt.axis("off")
plt.title(y_test.iloc[0])
plt.show()

# %%
img_train=np.array(img_train)
img_test=np.array(img_test)

# %%
train=img_train
train.shape
# Out:
# (2722, 256, 256, 3)

# %%
train.resize(train.shape[0],train.shape[1]*train.shape[2]*train.shape[3])
train.shape
# Out:
# (2722, 196608)

# %%
test=img_test
test.shape
# Out:
# (1341, 256, 256, 3)

# %%
test.resize(test.shape[0],test.shape[1]*test.shape[2]*test.shape[3])
test.shape
# Out:
# (1341, 196608)

# %%
from sklearn.linear_model import LogisticRegression
import pandas as pd

# %%
lr=LogisticRegression(class_weight='balanced')

# %%
lr.fit(train,y_train)
# Out:
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# LogisticRegression(C=1.0, class_weight='balanced', dual=False,
#           fit_intercept=True, intercept_scaling=1, max_iter=100,
#           multi_class='warn', n_jobs=None, penalty='l2', random_state=None,
#           solver='warn', tol=0.0001, verbose=0, warm_start=False)

# %%
import pickle
pickle.dump(lr, open('Logistic_Regression_Baseline_Segmented_Kaggle.sav', 'wb'))

# %%
#lr = pickle.load(open('Logistic_Regression_Baseline_Segmented_Kaggle.sav', 'rb'))

# %%
preds=lr.predict(test)

# %%
from sklearn.metrics import confusion_matrix,classification_report

# %%
import seaborn as sns
label=['Black_rot','Esca_(Black_Measles)','Leaf_blight_(Isariopsis_Leaf_Spot)','healthy']
sns.heatmap(confusion_matrix(y_test,preds),annot=True,square=True,fmt='g',xticklabels=label,yticklabels=label)
plt.title('Confusion matrix')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

# %%
print(classification_report(preds,y_test))
# Out:
#                                     precision    recall  f1-score   support
#
#                          Black_rot       0.75      0.73      0.74       400
#               Esca_(Black_Measles)       0.81      0.85      0.83       433
# Leaf_blight_(Isariopsis_Leaf_Spot)       0.96      0.94      0.95       362
#                            healthy       0.78      0.75      0.76       146
#
#                          micro avg       0.83      0.83      0.83      1341
#                          macro avg       0.82      0.82      0.82      1341
#                       weighted avg       0.83      0.83      0.83      1341

# %%
print(datetime.datetime.now()-start)
# Out:
# 0:13:15.571143
